# %%
#트럼프 트위터를 통한 선거 당선을 위한 대중의 관심도 분석

# %%
import pandas as pd

df = pd.read_csv('realdonaldtrump.csv')

df['date'].astype('string')
# 트럼프 트위터의 월별 리트윗 증감 그래프(1번)와 트럼프 트위터의 월별 favorite 증감 그래프(2번) 도출
df['date']=df['date'].str[0:7]
df = df.drop(['id','link','content','mentions','hashtags'],axis=1)
df = df.set_index("date")
x1 = df.index
y1 = df['retweets']

x2 = df.index
y2 = df['favorites']


plt.figure(figsize = (60, 24)) # 전체 figure 크기

#================= 1번째 데이터 시각화 =================#
plt.subplot(2, 1, 1)
# 선 그래프 시각화 옵션
## color: 선 색깔, linewidth: 선 굵기, marker 선택
plt.plot(y1, 'o-', color = 'blue', linewidth = 3)
# 값 출력
for i, v in enumerate(x1):
    plt.text(v, y1[i], y1[i],
             fontsize = 25, # 텍스트 크기
             color = 'blue', # 텍스트 색깔
             horizontalalignment ='center', # 수평정렬 옵션
             verticalalignment = 'bottom')  # 수직정렬 옵션
plt.xticks(x1, fontsize = 18, rotation = 15) # x축 눈금
plt.yticks(fontsize = 30) # y축 눈금
plt.xlabel('DATE', fontsize = 30) # x축 이름
plt.ylabel('retweets', fontsize = 30)  # y축 이름
plt.title('retweets graph', fontsize = 50) # 그래프 제목
#==================================================#

#================= 2번째 데이터 시각화 =================#
plt.subplot(2, 1, 2)
plt.plot(y2, '.-', color = 'orange', linewidth = 3)
for i, v in enumerate(x2):
    plt.text(v, y2[i], y2[i],
             fontsize = 25, 
             color = 'blue',
             horizontalalignment ='center',
             verticalalignment = 'bottom')
plt.xticks(x2, fontsize = 18, rotation = 15)
plt.yticks(fontsize = 30)
plt.xlabel('DATE', fontsize = 30)
plt.ylabel('favorites', fontsize = 30)
plt.title('favorites graph', fontsize = 50)
#==================================================#

plt.tight_layout() # 그래프 간 간격 조절
plt.show()

# %%
#가설 검증: 선거철에 가까울 수록, 특히 2011년 대선 후 대중들의 관심도가 증가한 것을 확인할 수 있음.
df = pd.read_csv('realdonaldtrump.csv')

df
# Out:
#                         id                                               link  \
# 0               1698308935  https://twitter.com/realDonaldTrump/status/169...
# 1               1701461182  https://twitter.com/realDonaldTrump/status/170...
# 2               1737479987  https://twitter.com/realDonaldTrump/status/173...
# 3               1741160716  https://twitter.com/realDonaldTrump/status/174...
# 4               1773561338  https://twitter.com/realDonaldTrump/status/177...
# ...                    ...                                                ...
# 43347  1273405198698975232  https://twitter.com/realDonaldTrump/status/127...
# 43348  1273408026968457216  https://twitter.com/realDonaldTrump/status/127...
# 43349  1273442195161387008  https://twitter.com/realDonaldTrump/status/127...
# 43350  1273442469066276864  https://twitter.com/realDonaldTrump/status/127...
# 43351  1273442528411385858  https://twitter.com/realDonaldTrump/status/127...
#
# ...

# %%
import re

def clean(text):
# Removes all special characters and numericals leaving the alphabets
    text = re.sub('[^A-Za-z]+@', ' ', str(text))
    return text

# Cleaning the text in the review column
df['Cleaned text'] = df['content'].apply(clean)


dk = df.dropna(axis = 0)
dk
# Out:
#                         id                                               link  \
# 236      47672443254476800  https://twitter.com/realDonaldTrump/status/476...
# 237      47673273869283328  https://twitter.com/realDonaldTrump/status/476...
# 239      47755962928463872  https://twitter.com/realDonaldTrump/status/477...
# 265      56092783328505856  https://twitter.com/realDonaldTrump/status/560...
# 280      61155764227674112  https://twitter.com/realDonaldTrump/status/611...
# ...                    ...                                                ...
# 43260  1270828961854099459  https://twitter.com/realDonaldTrump/status/127...
# 43261  1270832498449186817  https://twitter.com/realDonaldTrump/status/127...
# 43277  1271162934337527808  https://twitter.com/realDonaldTrump/status/127...
# 43282  1271166408596963328  https://twitter.com/realDonaldTrump/status/127...
# 43341  1273032175718449155  https://twitter.com/realDonaldTrump/status/127...
#
# ...

# %%
wordcloud = WordCloud(stopwords = STOPWORDS,
                      background_color = 'black', #배경색
                      width = 800,
                      height = 600).generate(' '.join(dk['Cleaned text']))
                      
plt.figure(figsize = (15, 10)) # (가로인치, 세로인치)
plt.axis("off") # 축눈금 제거
plt.imshow(wordcloud) # 이미지가 표시되도록
plt.show() # 최종 출력문
#분석 의견: 대중의 관심을 많이 받은 트럼프의 트윗은 대부분 자신감을 강조한(realdonaldtrump, makeAmericagreatagain 등)단어를 포함함. 
#이에 따라 향후 대중의 긍정적인 관심(favorite과 retweets)을 증폭시키기 위해서는 자신감을 강조한 표현을 주로 사용하는 것을 제안하는 바임.
